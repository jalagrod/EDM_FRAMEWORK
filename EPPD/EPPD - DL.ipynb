# %%
#!conda create -n ag python=3.10
#!conda activate ag
#!conda install -c conda-forge mamba
#!mamba install -c conda-forge -c pytorch -c nvidia autogluon "pytorch=*=*cuda*"
#!mamba install -c conda-forge "ray-tune >=2.6.3,<2.7" "ray-default >=2.6.3,<2.7"  # install ray for faster training

# %%
#!pip install autogluon==1.0.0
#!pip install --upgrade numpy pandas scipy
#!pip install numpy==1.26.4
#!pip install pyJoules
#!pip install mxnet-cu110
#!pip install jedi
#!pip install setuptools
#!pip install scikit-learn==1.3.0
#!pip install pandas==2.0.0
#!pip install fsspec==2023.1.0
#!pip install torch==2.0.1+cu118 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
#cls
# !pip install cudatoolkit

# %%
import torch
print(torch.cuda.is_available())  # Should be True
print(torch.cuda.device_count())  # Should be > 0
# Out:
# True
# 1

# %%
import pandas as pd
import numpy as np
import logging
import os
import time
from sklearn.feature_selection import mutual_info_classif, VarianceThreshold
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularPredictor

# %% [markdown]
# # Deep Learning Part

# %%
FILENAME = "EPPD"
DATA_PATH = "eppd.csv"
TARGET = "PlacedOrNot" 
SELECTED_METRICS = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
KFOLD=10    

# Load dataset
df = pd.read_csv(DATA_PATH)
dummy_gender = pd.get_dummies(df['Gender'])
dummy_stream = pd.get_dummies(df['Stream'])
df.columns = df.columns.str.replace(' ', '')
df = pd.concat([df.drop(["Gender", "Stream"], axis = 1), dummy_gender, dummy_stream], axis = 1)
df = df[['Age', 'Male', 'Female',
            'Electronics And Communication',
            'Computer Science', 'Information Technology',
            'Mechanical', 'Electrical', "Civil",
            'Internships','CGPA','Hostel',
            'HistoryOfBacklogs', 'PlacedOrNot']]

# Separate features and target
X = df.drop(columns=[TARGET])
y = df[TARGET]

# Feature Selection: Variance Filtering
selector_variance = VarianceThreshold(threshold=(.8 * (1 - .8)))
X_variance = selector_variance.fit_transform(X)
variance_columns = X.columns[selector_variance.get_support()]

# Feature Selection: Mutual Information Filtering
mi_scores = mutual_info_classif(X_variance, y, discrete_features='auto')
mi_threshold = 0.01 
mi_mask = mi_scores > mi_threshold
X_mi = X_variance[:, mi_mask]
mi_columns = variance_columns[mi_mask]

# Create a DataFrame with the selected features
X_selected = pd.DataFrame(X_mi, columns=mi_columns)

# Create a new DataFrame with the selected features and selected class
df_selected = X_selected.copy()
df_selected[TARGET] = y
for gpu_available in [0, 1]:
    for validation_type in ['kfold']:
        start_time = time.time()        
        train_data = df_selected
        test_data = df_selected
        
        path = f"GPU_{gpu_available}_{FILENAME}_DL_VALIDATION_{validation_type}"

        # Create the dir if not exist
        os.makedirs(path, exist_ok=True)
        predictor = TabularPredictor(label=TARGET,  path=path, problem_type="binary")
        if(gpu_available):
            predictor.fit(train_data, num_bag_folds=KFOLD, verbosity=2, num_gpus=1, excluded_model_types= ['RF', 'KNN', 'GBM','XGB','CAT','XT','LR'], presets="best_quality")
        else:
            predictor.fit(train_data, num_bag_folds=KFOLD, verbosity=2, excluded_model_types= ['RF', 'KNN', 'GBM','XGB','CAT','XT','LR'], presets="best_quality")
        
        # Test data evaluaton
        # performance = predictor.evaluate(test_data, extra_metrics=SELECTED_METRICS)
        # print(performance)

        # Laderboard
        dfl = predictor.leaderboard(test_data, silent=True, extra_metrics=SELECTED_METRICS)
        print(dfl)

        # Get best model metrics
        # best_model = predictor.get_model_best()
        # performance = predictor.evaluate(test_data, model=best_model)
        # print(f"Performance of the best model ({best_model}):")
        # print(performance)
             
        end_time = time.time()
        execution_time_minutes = (end_time - start_time) / 60

        filename = f"GPU_{gpu_available}_{FILENAME}_DL_VALIDATION_{validation_type}_TIME_{execution_time_minutes:.2f}.csv"

        print(filename)
        dfl.to_csv(filename, index=False)
# Out:
# [codecarbon INFO @ 09:48:15] [setup] RAM Tracking...
# [codecarbon INFO @ 09:48:15] [setup] GPU Tracking...
# [codecarbon INFO @ 09:48:15] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 09:48:15] [setup] CPU Tracking...
# [codecarbon WARNING @ 09:48:15] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 09:48:16] CPU Model on constant consumption mode: AMD Ryzen 9 5950X 16-Core Processor
# [codecarbon INFO @ 09:48:16] >>> Tracker's metadata:
# [codecarbon INFO @ 09:48:16]   Platform system: Windows-10-10.0.22631-SP0
# [codecarbon INFO @ 09:48:16]   Python version: 3.11.4
# [codecarbon INFO @ 09:48:16]   CodeCarbon version: 2.5.0
# [codecarbon INFO @ 09:48:16]   Available RAM : 63.944 GB
# [codecarbon INFO @ 09:48:16]   CPU count: 32
# [codecarbon INFO @ 09:48:16]   CPU model: AMD Ryzen 9 5950X 16-Core Processor
# [codecarbon INFO @ 09:48:16]   GPU count: 1
# [codecarbon INFO @ 09:48:16]   GPU model: 1 x NVIDIA GeForce RTX 3090
# [codecarbon INFO @ 09:48:16] Saving emissions data to file c:\Users\JAL\Documents\GitHub\Art1\100\EPPD\emissions.csv
# Warning: path already exists! This predictor may overwrite an existing predictor! path="GPU_0_EPPD_DL_VALIDATION_7525"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.4
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          32
# Memory Avail:       50.80 GB / 63.94 GB (79.4%)
# Disk Space Avail:   223.73 GB / 464.98 GB (48.1%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=10, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-07-16 09:48:19,756	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "GPU_0_EPPD_DL_VALIDATION_7525\ds_sub_fit\sub_fit_ho"
# (_dystack pid=12260) Running DyStack sub-fit ...
# (_dystack pid=12260) Beginning AutoGluon training ... Time limit = 896s
# (_dystack pid=12260) AutoGluon will save models to "GPU_0_EPPD_DL_VALIDATION_7525\ds_sub_fit\sub_fit_ho"
# (_dystack pid=12260) Train Data Rows:    1976
# (_dystack pid=12260) Train Data Columns: 2
# (_dystack pid=12260) Label Column:       PlacedOrNot
# (_dystack pid=12260) Problem Type:       binary
# (_dystack pid=12260) Preprocessing data ...
# (_dystack pid=12260) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=12260) Using Feature Generators to preprocess the data ...
# (_dystack pid=12260) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=12260) 	Available Memory:                    50865.56 MB
# (_dystack pid=12260) 	Train Data (Original)  Memory Usage: 0.03 MB (0.0% of available memory)
# (_dystack pid=12260) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=12260) 	Stage 1 Generators:
# (_dystack pid=12260) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=12260) 	Stage 2 Generators:
# (_dystack pid=12260) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=12260) 	Stage 3 Generators:
# (_dystack pid=12260) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=12260) 	Stage 4 Generators:
# (_dystack pid=12260) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=12260) 	Stage 5 Generators:
# (_dystack pid=12260) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=12260) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=12260) 		('int', []) : 2 | ['Internships', 'CGPA']
# (_dystack pid=12260) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=12260) 		('int', []) : 2 | ['Internships', 'CGPA']
# (_dystack pid=12260) 	0.0s = Fit runtime
# (_dystack pid=12260) 	2 features in original data used to generate 2 features in processed data.
# (_dystack pid=12260) 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# (_dystack pid=12260) Data preprocessing and feature engineering runtime = 0.03s ...
# (_dystack pid=12260) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=12260) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=12260) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=12260) User-specified model hyperparameters to be fit:
# (_dystack pid=12260) {
# (_dystack pid=12260) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=12260) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=12260) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=12260) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=12260) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=12260) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=12260) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=12260) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=12260) }
# (_dystack pid=12260) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=12260) Excluded models: ['RF', 'GBM', 'KNN', 'XT', 'CAT', 'XGB'] (Specified by `excluded_model_types`)
# (_dystack pid=12260) Fitting 44 L1 models ...
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 597.06s of the 895.81s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.78s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 589.05s of the 887.81s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8482	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.77s	 = Training   runtime
# (_dystack pid=12260) 	0.02s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 582.27s of the 881.03s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.64s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 574.73s of the 873.49s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8497	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.56s	 = Training   runtime
# (_dystack pid=12260) 	0.08s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 566.14s of the 864.9s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8487	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.44s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 557.83s of the 856.58s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8487	 = Validation score   (accuracy)
# (_dystack pid=12260) 	10.35s	 = Training   runtime
# (_dystack pid=12260) 	0.13s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 545.59s of the 844.35s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.88s	 = Training   runtime
# (_dystack pid=12260) 	0.07s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 537.9s of the 836.65s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	7.57s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 528.47s of the 827.22s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8436	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.94s	 = Training   runtime
# (_dystack pid=12260) 	0.02s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 522.74s of the 821.49s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8462	 = Validation score   (accuracy)
# (_dystack pid=12260) 	8.59s	 = Training   runtime
# (_dystack pid=12260) 	0.11s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 512.1s of the 810.86s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8462	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.89s	 = Training   runtime
# (_dystack pid=12260) 	0.07s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 506.39s of the 805.15s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8456	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.42s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 501.89s of the 800.65s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8467	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.1s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 496.72s of the 795.48s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	11.3s	 = Training   runtime
# (_dystack pid=12260) 	0.12s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 483.36s of the 782.12s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.95s	 = Training   runtime
# (_dystack pid=12260) 	0.08s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 475.6s of the 774.35s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8497	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.09s	 = Training   runtime
# (_dystack pid=12260) 	0.02s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 469.64s of the 768.39s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8492	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.03s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 461.73s of the 760.48s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8467	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.31s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 455.57s of the 754.32s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8467	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.17s	 = Training   runtime
# (_dystack pid=12260) 	0.02s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 450.49s of the 749.24s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8497	 = Validation score   (accuracy)
# (_dystack pid=12260) 	22.13s	 = Training   runtime
# (_dystack pid=12260) 	0.18s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 426.46s of the 725.22s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8487	 = Validation score   (accuracy)
# (_dystack pid=12260) 	9.79s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 414.89s of the 713.64s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8456	 = Validation score   (accuracy)
# (_dystack pid=12260) 	10.26s	 = Training   runtime
# (_dystack pid=12260) 	0.15s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 402.74s of the 701.49s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8467	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.13s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 396.46s of the 695.21s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8249	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.12s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 391.44s of the 690.19s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8097	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.02s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 386.34s of the 685.09s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.06s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 380.24s of the 679.0s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.61s	 = Training   runtime
# (_dystack pid=12260) 	0.02s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 375.76s of the 674.51s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8462	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.48s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 368.25s of the 667.0s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8482	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.84s	 = Training   runtime
# (_dystack pid=12260) 	0.08s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 361.58s of the 660.33s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8477	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.4s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 355.1s of the 653.85s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	9.07s	 = Training   runtime
# (_dystack pid=12260) 	0.1s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 343.95s of the 642.71s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8492	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.15s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 338.94s of the 637.69s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8446	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.7s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 334.17s of the 632.92s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8467	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.53s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 325.63s of the 624.38s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8436	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.85s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 320.92s of the 619.67s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8487	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.01s	 = Training   runtime
# (_dystack pid=12260) 	0.07s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r135_BAG_L1 ... Training model for up to 314.72s of the 613.47s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8502	 = Validation score   (accuracy)
# (_dystack pid=12260) 	7.39s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r4_BAG_L1 ... Training model for up to 305.17s of the 603.93s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8487	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.53s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 299.78s of the 598.53s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8482	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.39s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 294.31s of the 593.06s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	22.43s	 = Training   runtime
# (_dystack pid=12260) 	0.16s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 269.74s of the 568.5s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8436	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.86s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 265.07s of the 563.82s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8467	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.72s	 = Training   runtime
# (_dystack pid=12260) 	0.01s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 260.29s of the 559.04s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8487	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.25s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 252.08s of the 550.83s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8477	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.65s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 543.21s of remaining time.
# (_dystack pid=12260) 	Ensemble Weights: {'NeuralNetFastAI_r95_BAG_L1': 1.0}
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	0.07s	 = Training   runtime
# (_dystack pid=12260) 	0.0s	 = Validation runtime
# (_dystack pid=12260) Excluded models: ['RF', 'GBM', 'KNN', 'XT', 'CAT', 'XGB'] (Specified by `excluded_model_types`)
# (_dystack pid=12260) Fitting 44 L2 models ...
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 543.13s of the 543.08s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.57s	 = Training   runtime
# (_dystack pid=12260) 	0.07s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 537.7s of the 537.66s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.64s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 531.02s of the 530.97s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.28s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 522.92s of the 522.87s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	7.27s	 = Training   runtime
# (_dystack pid=12260) 	0.11s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 513.81s of the 513.76s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.69s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 505.24s of the 505.19s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	10.64s	 = Training   runtime
# (_dystack pid=12260) 	0.12s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 492.77s of the 492.73s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.66s	 = Training   runtime
# (_dystack pid=12260) 	0.08s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 485.23s of the 485.19s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	7.31s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 475.97s of the 475.92s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8502	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.19s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r11_BAG_L2 ... Training model for up to 469.97s of the 469.93s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	8.83s	 = Training   runtime
# (_dystack pid=12260) 	0.11s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r103_BAG_L2 ... Training model for up to 459.24s of the 459.2s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8532	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.28s	 = Training   runtime
# (_dystack pid=12260) 	0.07s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r14_BAG_L2 ... Training model for up to 453.08s of the 453.04s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.86s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r143_BAG_L2 ... Training model for up to 448.26s of the 448.21s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.12s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r156_BAG_L2 ... Training model for up to 443.25s of the 443.2s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	9.06s	 = Training   runtime
# (_dystack pid=12260) 	0.13s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r95_BAG_L2 ... Training model for up to 432.2s of the 432.16s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8517	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.44s	 = Training   runtime
# (_dystack pid=12260) 	0.09s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r41_BAG_L2 ... Training model for up to 424.89s of the 424.85s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8517	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.83s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r158_BAG_L2 ... Training model for up to 419.03s of the 418.99s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8532	 = Validation score   (accuracy)
# (_dystack pid=12260) 	6.13s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r37_BAG_L2 ... Training model for up to 411.05s of the 411.0s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8537	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.41s	 = Training   runtime
# (_dystack pid=12260) 	0.07s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r197_BAG_L2 ... Training model for up to 404.72s of the 404.67s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8517	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.32s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r134_BAG_L2 ... Training model for up to 399.56s of the 399.52s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	24.81s	 = Training   runtime
# (_dystack pid=12260) 	0.18s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r143_BAG_L2 ... Training model for up to 372.92s of the 372.87s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8537	 = Validation score   (accuracy)
# (_dystack pid=12260) 	10.51s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r111_BAG_L2 ... Training model for up to 360.63s of the 360.59s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	10.1s	 = Training   runtime
# (_dystack pid=12260) 	0.16s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r31_BAG_L2 ... Training model for up to 348.72s of the 348.67s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8512	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.61s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r65_BAG_L2 ... Training model for up to 343.09s of the 343.04s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.0s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r88_BAG_L2 ... Training model for up to 338.13s of the 338.09s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8517	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.16s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r87_BAG_L2 ... Training model for up to 332.94s of the 332.9s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.57s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r71_BAG_L2 ... Training model for up to 327.37s of the 327.32s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8507	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.56s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r185_BAG_L2 ... Training model for up to 322.88s of the 322.84s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8517	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.57s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r160_BAG_L2 ... Training model for up to 316.36s of the 316.31s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8532	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.94s	 = Training   runtime
# (_dystack pid=12260) 	0.08s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r69_BAG_L2 ... Training model for up to 309.47s of the 309.42s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.37s	 = Training   runtime
# (_dystack pid=12260) 	0.08s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r138_BAG_L2 ... Training model for up to 303.05s of the 303.0s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	10.19s	 = Training   runtime
# (_dystack pid=12260) 	0.11s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r172_BAG_L2 ... Training model for up to 290.8s of the 290.76s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.13s	 = Training   runtime
# (_dystack pid=12260) 	0.11s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r76_BAG_L2 ... Training model for up to 285.87s of the 285.82s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8517	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.76s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r121_BAG_L2 ... Training model for up to 281.09s of the 281.03s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8512	 = Validation score   (accuracy)
# (_dystack pid=12260) 	8.07s	 = Training   runtime
# (_dystack pid=12260) 	0.03s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r127_BAG_L2 ... Training model for up to 271.07s of the 271.01s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8517	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.84s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r194_BAG_L2 ... Training model for up to 266.4s of the 266.36s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	4.05s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r135_BAG_L2 ... Training model for up to 260.33s of the 260.29s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8522	 = Validation score   (accuracy)
# (_dystack pid=12260) 	5.08s	 = Training   runtime
# (_dystack pid=12260) 	0.08s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r4_BAG_L2 ... Training model for up to 253.2s of the 253.16s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8537	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.65s	 = Training   runtime
# (_dystack pid=12260) 	0.04s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r36_BAG_L2 ... Training model for up to 247.57s of the 247.53s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.65s	 = Training   runtime
# (_dystack pid=12260) 	0.06s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r100_BAG_L2 ... Training model for up to 241.92s of the 241.88s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8532	 = Validation score   (accuracy)
# (_dystack pid=12260) 	24.46s	 = Training   runtime
# (_dystack pid=12260) 	0.19s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetFastAI_r187_BAG_L2 ... Training model for up to 215.58s of the 215.54s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=12260) 	0.8527	 = Validation score   (accuracy)
# (_dystack pid=12260) 	3.2s	 = Training   runtime
# (_dystack pid=12260) 	0.05s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r19_BAG_L2 ... Training model for up to 210.57s of the 210.53s of remaining time.
# (_dystack pid=12260) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=12260) 	0.8512	 = Validation score   (accuracy)
# (_dystack pid=12260) 	2.96s	 = Training   runtime
# (_dystack pid=12260) 	0.07s	 = Validation runtime
# (_dystack pid=12260) Fitting model: NeuralNetTorch_r1_BAG_L2 ... Training model for up to 205.63s of the 205.59s of remaining time.
# ...
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8469	 = Validation score   (accuracy)
# 	22.88s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 1450.22s of the 1450.22s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8466	 = Validation score   (accuracy)
# 	45.2s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 1403.43s of the 1403.43s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8466	 = Validation score   (accuracy)
# 	24.31s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 1377.51s of the 1377.51s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8466	 = Validation score   (accuracy)
# 	19.0s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 1356.89s of the 1356.89s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8466	 = Validation score   (accuracy)
# 	34.63s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 1320.63s of the 1320.63s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8466	 = Validation score   (accuracy)
# 	56.32s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 1262.66s of the 1262.66s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8473	 = Validation score   (accuracy)
# 	52.96s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1207.95s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r191_BAG_L1': 1.0}
# 	0.8476	 = Validation score   (accuracy)
# 	0.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1704.18s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 9473.2 rows/s (297 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("GPU_1_EPPD_DL_VALIDATION_kfold")
#                           model  score_test  accuracy  precision    recall  \
# 0     NeuralNetTorch_r14_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 1     NeuralNetTorch_r76_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 2     NeuralNetTorch_r19_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 3     NeuralNetTorch_r71_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 4     NeuralNetTorch_r41_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 5     NeuralNetTorch_r87_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 6    NeuralNetTorch_r197_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 7         NeuralNetTorch_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 8     NeuralNetTorch_r36_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 9     NeuralNetTorch_r86_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 10   NeuralNetTorch_r185_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 11    NeuralNetTorch_r31_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 12     NeuralNetTorch_r1_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 13    NeuralNetTorch_r79_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 14   NeuralNetTorch_r121_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 15  NeuralNetFastAI_r187_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 16   NeuralNetTorch_r135_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 17  NeuralNetFastAI_r143_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 18   NeuralNetTorch_r158_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 19   NeuralNetFastAI_r88_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 20    NeuralNetTorch_r89_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 21    NeuralNetTorch_r22_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 22   NeuralNetFastAI_r65_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 23  NeuralNetFastAI_r127_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 24  NeuralNetFastAI_r172_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 25    NeuralNetTorch_r30_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 26   NeuralNetTorch_r143_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 27    NeuralNetFastAI_r4_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 28   NeuralNetFastAI_r37_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 29  NeuralNetFastAI_r134_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 30  NeuralNetFastAI_r100_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 31       NeuralNetFastAI_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 32  NeuralNetFastAI_r194_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 33  NeuralNetFastAI_r103_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 34  NeuralNetFastAI_r191_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 35          WeightedEnsemble_L2    0.845920  0.845920   0.947050  0.763880
# 36   NeuralNetFastAI_r69_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 37   NeuralNetFastAI_r95_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 38  NeuralNetFastAI_r145_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 39  NeuralNetFastAI_r160_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 40  NeuralNetFastAI_r138_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 41   NeuralNetFastAI_r11_BAG_L1    0.845920  0.845920   0.947050  0.763880
# 42  NeuralNetFastAI_r102_BAG_L1    0.843898  0.843898   0.941441  0.765101
# 43  NeuralNetFastAI_r156_BAG_L1    0.843898  0.843898   0.941441  0.765101
# 44  NeuralNetFastAI_r111_BAG_L1    0.843898  0.843898   0.941441  0.765101
#
#          f1   roc_auc  score_val eval_metric  pred_time_test  pred_time_val  \
# 0   0.84566  0.893171   0.846258    accuracy        0.103338       0.023159
# 1   0.84566  0.892185   0.846258    accuracy        0.106712       0.024050
# 2   0.84566  0.892183   0.846595    accuracy        0.107661       0.020049
# 3   0.84566  0.892338   0.846595    accuracy        0.108938       0.020347
# 4   0.84566  0.892471   0.846932    accuracy        0.133653       0.002024
# 5   0.84566  0.892357   0.847269    accuracy        0.141189       0.023656
# 6   0.84566  0.887993   0.846258    accuracy        0.141912       0.022133
# 7   0.84566  0.892284   0.846932    accuracy        0.153680       0.046255
# 8   0.84566  0.887088   0.846595    accuracy        0.154498       0.022992
# 9   0.84566  0.893148   0.846258    accuracy        0.165624       0.009943
# 10  0.84566  0.892855   0.846258    accuracy        0.177392       0.026397
# 11  0.84566  0.886764   0.847269    accuracy        0.202626       0.022548
# 12  0.84566  0.893256   0.846595    accuracy        0.208811       0.028049
# 13  0.84566  0.892207   0.846932    accuracy        0.218760       0.030141
# 14  0.84566  0.888159   0.846932    accuracy        0.246396       0.032016
# 15  0.84566  0.885017   0.846595    accuracy        0.253490       0.050296
# 16  0.84566  0.892244   0.846932    accuracy        0.253922       0.037534
# 17  0.84566  0.884798   0.846258    accuracy        0.255583       0.084015
# 18  0.84566  0.886656   0.846932    accuracy        0.257357       0.049967
# 19  0.84566  0.881640   0.845920    accuracy        0.260044       0.045555
# 20  0.84566  0.892555   0.847269    accuracy        0.261615       0.027141
# 21  0.84566  0.892677   0.846932    accuracy        0.265041       0.039431
# 22  0.84566  0.879407   0.846258    accuracy        0.265706       0.050114
# 23  0.84566  0.884212   0.846932    accuracy        0.270989       0.051559
# 24  0.84566  0.884646   0.847269    accuracy        0.290057       0.048462
# 25  0.84566  0.892431   0.847269    accuracy        0.295576       0.068018
# 26  0.84566  0.892186   0.846595    accuracy        0.316615       0.066247
# 27  0.84566  0.882664   0.846932    accuracy        0.340174       0.061241
# 28  0.84566  0.887756   0.847269    accuracy        0.349705       0.077509
# 29  0.84566  0.882934   0.846258    accuracy        0.362062       0.093759
# 30  0.84566  0.885265   0.846595    accuracy        0.368875       0.070767
# 31  0.84566  0.887861   0.846932    accuracy        0.370574       0.046878
# 32  0.84566  0.882807   0.845920    accuracy        0.433484       0.074456
# 33  0.84566  0.889309   0.846258    accuracy        0.435647       0.057222
# 34  0.84566  0.884321   0.847606    accuracy        0.521688       0.031251
# 35  0.84566  0.884321   0.847606    accuracy        0.527204       0.032252
# 36  0.84566  0.887760   0.846258    accuracy        0.531057       0.088906
# 37  0.84566  0.889416   0.846258    accuracy        0.587228       0.078132
# 38  0.84566  0.892892   0.846595    accuracy        0.593505       0.108644
# 39  0.84566  0.886150   0.846258    accuracy        0.636780       0.091722
# 40  0.84566  0.884343   0.847606    accuracy        0.660446       0.095131
# 41  0.84566  0.881617   0.846595    accuracy        0.671907       0.066388
# 42  0.84416  0.883116   0.846258    accuracy        0.253489       0.046879
# 43  0.84416  0.881459   0.845920    accuracy        0.259134       0.051882
# 44  0.84416  0.883252   0.838166    accuracy        0.289306       0.046878
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   32.388926                 0.103338                0.023159
# 1   34.834142                 0.106712                0.024050
# 2   34.632104                 0.107661                0.020049
# 3   32.956742                 0.108938                0.020347
# 4   40.919216                 0.133653                0.002024
# 5   44.719018                 0.141189                0.023656
# 6   36.312698                 0.141912                0.022133
# 7   40.831959                 0.153680                0.046255
# 8   45.202051                 0.154498                0.022992
# 9   46.742363                 0.165624                0.009943
# 10  53.564718                 0.177392                0.026397
# 11  49.281077                 0.202626                0.022548
# 12  56.322237                 0.208811                0.028049
# 13  53.665336                 0.218760                0.030141
# 14  62.660794                 0.246396                0.032016
# 15  18.996677                 0.253490                0.050296
# 16  70.065375                 0.253922                0.037534
# 17  17.661827                 0.255583                0.084015
# 18  59.989861                 0.257357                0.049967
# 19  21.064928                 0.260044                0.045555
# 20  52.961336                 0.261615                0.027141
# 21  64.975753                 0.265041                0.039431
# 22  20.900664                 0.265706                0.050114
# 23  18.390614                 0.270989                0.051559
# 24  20.290679                 0.290057                0.048462
# 25  71.675792                 0.295576                0.068018
# 26  81.233600                 0.316615                0.066247
# 27  22.877428                 0.340174                0.061241
# 28  21.941343                 0.349705                0.077509
# 29  21.370126                 0.362062                0.093759
# 30  24.306907                 0.368875                0.070767
# 31  22.119156                 0.370574                0.046878
# 32  25.394044                 0.433484                0.074456
# 33  23.466714                 0.435647                0.057222
# 34  32.085542                 0.521688                0.031251
# 35  32.164351                 0.005517                0.001000
# 36  30.053281                 0.531057                0.088906
# 37  30.923897                 0.587228                0.078132
# 38  31.849061                 0.593505                0.108644
# 39  31.603493                 0.636780                0.091722
# 40  42.580976                 0.660446                0.095131
# 41  37.325915                 0.671907                0.066388
# 42  17.516092                 0.253489                0.046879
# 43  18.018505                 0.259134                0.051882
# 44  18.077826                 0.289306                0.046878
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0           32.388926            1       True         12
# 1           34.834142            1       True         33
# 2           34.632104            1       True         42
# 3           32.956742            1       True         27
# 4           40.919216            1       True         16
# 5           44.719018            1       True         26
# 6           36.312698            1       True         19
# 7           40.831959            1       True          2
# 8           45.202051            1       True         39
# 9           46.742363            1       True          9
# 10          53.564718            1       True         28
# 11          49.281077            1       True         23
# 12          56.322237            1       True         43
# 13          53.665336            1       True          3
# 14          62.660794            1       True         34
# 15          18.996677            1       True         41
# 16          70.065375            1       True         37
# 17          17.661827            1       True         13
# 18          59.989861            1       True         17
# 19          21.064928            1       True         25
# 20          52.961336            1       True         44
# 21          64.975753            1       True          5
# 22          20.900664            1       True         24
# 23          18.390614            1       True         35
# 24          20.290679            1       True         32
# 25          71.675792            1       True          8
# 26          81.233600            1       True         21
# 27          22.877428            1       True         38
# 28          21.941343            1       True         18
# 29          21.370126            1       True         20
# 30          24.306907            1       True         40
# 31          22.119156            1       True          1
# 32          25.394044            1       True         36
# 33          23.466714            1       True         11
# 34          32.085542            1       True          4
# 35           0.078809            2       True         45
# 36          30.053281            1       True         30
# 37          30.923897            1       True         15
# 38          31.849061            1       True          7
# 39          31.603493            1       True         29
# 40          42.580976            1       True         31
# 41          37.325915            1       True         10
# 42          17.516092            1       True          6
# 43          18.018505            1       True         14
# 44          18.077826            1       True         22
# GPU_1_EPPD_DL_VALIDATION_kfold_TIME_40.10_EMISSION_0.042120.csv
