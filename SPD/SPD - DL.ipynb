# %%
#!conda create -n ag python=3.10
#!conda activate ag
#!conda install -c conda-forge mamba
#!mamba install -c conda-forge -c pytorch -c nvidia autogluon "pytorch=*=*cuda*"
#!mamba install -c conda-forge "ray-tune >=2.6.3,<2.7" "ray-default >=2.6.3,<2.7"  # install ray for faster training

# %%
#!pip install autogluon==1.0.0
#!pip install --upgrade numpy pandas scipy
#!pip install numpy==1.26.4
#!pip install pyJoules
#!pip install mxnet-cu110
#!pip install jedi
#!pip install setuptools
#!pip install scikit-learn==1.3.0
#!pip install pandas==2.0.0
#!pip install fsspec==2023.1.0
#!pip install torch==2.0.1+cu118 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
#cls
# !pip install cudatoolkit

# %%
import torch
print(torch.cuda.is_available())  # Should be True
print(torch.cuda.device_count())  # Should be > 0
# Out:
# True
# 1

# %%
import pandas as pd
import numpy as np
import logging
import os
import time
from sklearn.feature_selection import mutual_info_classif, VarianceThreshold
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularPredictor
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Deep Learning Part

# %%
FILENAME = "SPD"
DATA_PATH = "spd.csv"
TARGET = "G3" 
KFOLD=10    

# Load dataset
df = pd.read_csv(DATA_PATH)
df.columns = df.columns.str.replace(' ', '')
bins = [0, 10, 15, 20]
labels = ['failing', 'passing', 'excellent']
df['G3'] = pd.cut(df['G3'], bins=bins, labels=labels, right=False)

# Seleccionar las características más relevantes y la etiqueta
features = ['Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2']
data = df[features + [TARGET]]

# Separate features and target
X = data.drop(columns=[TARGET])
y = data[TARGET]

# Feature Selection: Variance Filtering
selector_variance = VarianceThreshold(threshold=(.8 * (1 - .8)))
X_variance = selector_variance.fit_transform(X)
variance_columns = X.columns[selector_variance.get_support()]

# Feature Selection: Mutual Information Filtering
mi_scores = mutual_info_classif(X_variance, y, discrete_features='auto')
mi_threshold = 0.01 
mi_mask = mi_scores > mi_threshold
X_mi = X_variance[:, mi_mask]
mi_columns = variance_columns[mi_mask]

# Create a DataFrame with the selected features
X_selected = pd.DataFrame(X_mi, columns=mi_columns)

# Create a new DataFrame with the selected features and selected class
df_selected = X_selected.copy()
df_selected[TARGET] = y

for gpu_available in [0, 1]:
    for validation_type in ['7525','kfold']:
        start_time = time.time()
        
        train_data = df_selected
        test_data = df_selected
        
        path = f"GPU_{gpu_available}_{FILENAME}_DL_VALIDATION_{validation_type}"

        # Create the dir if not exist
        os.makedirs(path, exist_ok=True)
        predictor = TabularPredictor(label=TARGET,  path=path, problem_type="multiclass")
        
        if(gpu_available):
            predictor.fit(train_data, num_bag_folds=KFOLD, verbosity=2, num_gpus=1, excluded_model_types= ['RF', 'KNN', 'GBM','XGB','CAT','XT','LR'], presets="best_quality")
        else:
            predictor.fit(train_data, num_bag_folds=KFOLD, verbosity=2, excluded_model_types= ['RF', 'KNN', 'GBM','XGB','CAT','XT','LR'], presets="best_quality")
        
        # Test data evaluaton
        y_pred = predictor.predict(test_data)
        y_true = test_data[TARGET]
        y_prob = predictor.predict_proba(test_data)

        accuracy = accuracy_score(y_true, y_pred)
        precision = precision_score(y_true, y_pred, average='weighted')
        recall = recall_score(y_true, y_pred, average='weighted')
        f1 = f1_score(y_true, y_pred, average='weighted')
        roc_auc = roc_auc_score(pd.get_dummies(y_true), y_prob, average='weighted', multi_class='ovr')

        df1 = pd.DataFrame({
            'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC'],
            'Score': [accuracy, precision, recall, f1, roc_auc]
        })

        emissions_filtering = tracker_filtering.stop()        
        end_time = time.time()
        execution_time_minutes = (end_time - start_time) / 60

        filename = f"GPU_{gpu_available}_{FILENAME}_DL_VALIDATION_{validation_type}_TIME_{execution_time_minutes:.2f}.csv"

        print(filename)
        df1.to_csv(filename, index=False)
# Out:
# [codecarbon INFO @ 17:43:57] [setup] RAM Tracking...
# [codecarbon INFO @ 17:43:57] [setup] GPU Tracking...
# [codecarbon INFO @ 17:43:57] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 17:43:57] [setup] CPU Tracking...
# [codecarbon WARNING @ 17:43:57] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 17:43:59] CPU Model on constant consumption mode: AMD Ryzen 9 5950X 16-Core Processor
# [codecarbon INFO @ 17:43:59] >>> Tracker's metadata:
# [codecarbon INFO @ 17:43:59]   Platform system: Windows-10-10.0.22631-SP0
# [codecarbon INFO @ 17:43:59]   Python version: 3.11.4
# [codecarbon INFO @ 17:43:59]   CodeCarbon version: 2.5.0
# [codecarbon INFO @ 17:43:59]   Available RAM : 63.944 GB
# [codecarbon INFO @ 17:43:59]   CPU count: 32
# [codecarbon INFO @ 17:43:59]   CPU model: AMD Ryzen 9 5950X 16-Core Processor
# [codecarbon INFO @ 17:43:59]   GPU count: 1
# [codecarbon INFO @ 17:43:59]   GPU model: 1 x NVIDIA GeForce RTX 3090
# [codecarbon INFO @ 17:43:59] Saving emissions data to file c:\Users\JAL\Documents\GitHub\Art1\100\SPD\emissions.csv
# Warning: path already exists! This predictor may overwrite an existing predictor! path="GPU_0_SPD_DL_VALIDATION_7525"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.4
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          32
# Memory Avail:       54.05 GB / 63.94 GB (84.5%)
# Disk Space Avail:   219.61 GB / 464.98 GB (47.2%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=10, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-07-17 17:44:02,302	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "GPU_0_SPD_DL_VALIDATION_7525\ds_sub_fit\sub_fit_ho"
# (_dystack pid=8576) Running DyStack sub-fit ...
# (_dystack pid=8576) Beginning AutoGluon training ... Time limit = 896s
# (_dystack pid=8576) AutoGluon will save models to "GPU_0_SPD_DL_VALIDATION_7525\ds_sub_fit\sub_fit_ho"
# (_dystack pid=8576) Train Data Rows:    432
# (_dystack pid=8576) Train Data Columns: 8
# (_dystack pid=8576) Label Column:       G3
# (_dystack pid=8576) Problem Type:       multiclass
# (_dystack pid=8576) Preprocessing data ...
# (_dystack pid=8576) Train Data Class Count: 3
# (_dystack pid=8576) Using Feature Generators to preprocess the data ...
# (_dystack pid=8576) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=8576) 	Available Memory:                    54543.06 MB
# (_dystack pid=8576) 	Train Data (Original)  Memory Usage: 0.03 MB (0.0% of available memory)
# (_dystack pid=8576) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=8576) 	Stage 1 Generators:
# (_dystack pid=8576) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=8576) 	Stage 2 Generators:
# (_dystack pid=8576) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=8576) 	Stage 3 Generators:
# (_dystack pid=8576) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=8576) 	Stage 4 Generators:
# (_dystack pid=8576) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=8576) 	Stage 5 Generators:
# (_dystack pid=8576) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=8576) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=8576) 		('int', []) : 8 | ['Fedu', 'studytime', 'failures', 'freetime', 'goout', ...]
# (_dystack pid=8576) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=8576) 		('int', []) : 8 | ['Fedu', 'studytime', 'failures', 'freetime', 'goout', ...]
# (_dystack pid=8576) 	0.0s = Fit runtime
# (_dystack pid=8576) 	8 features in original data used to generate 8 features in processed data.
# (_dystack pid=8576) 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# (_dystack pid=8576) Data preprocessing and feature engineering runtime = 0.02s ...
# (_dystack pid=8576) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=8576) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=8576) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=8576) User-specified model hyperparameters to be fit:
# (_dystack pid=8576) {
# (_dystack pid=8576) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=8576) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=8576) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=8576) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=8576) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=8576) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=8576) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=8576) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=8576) }
# (_dystack pid=8576) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=8576) Excluded models: ['KNN', 'GBM', 'CAT', 'XGB', 'RF', 'XT'] (Specified by `excluded_model_types`)
# (_dystack pid=8576) Fitting 44 L1 models ...
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 597.21s of the 896.05s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8912	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.24s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 588.73s of the 887.56s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8866	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.18s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 583.46s of the 882.3s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9144	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.07s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 578.45s of the 877.28s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8843	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.81s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 572.61s of the 871.44s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9051	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.33s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 567.19s of the 866.02s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.919	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.28s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 560.9s of the 859.73s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.41s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 555.45s of the 854.28s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9236	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.85s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 549.52s of the 848.35s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8843	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.39s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 544.18s of the 843.01s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9028	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.11s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 538.18s of the 837.01s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8843	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.07s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 532.88s of the 831.71s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8866	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.35s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 528.5s of the 827.34s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9306	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.21s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 521.25s of the 820.09s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9028	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.82s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 514.41s of the 813.25s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8958	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.43s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 508.9s of the 807.73s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.912	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.82s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 503.99s of the 802.82s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9236	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.05s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 497.92s of the 796.75s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9282	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.81s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 490.24s of the 789.08s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.919	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.27s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 485.98s of the 784.81s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=8576) 	7.63s	 = Training   runtime
# (_dystack pid=8576) 	0.08s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 476.27s of the 775.1s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9051	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.83s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 469.57s of the 768.4s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.919	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.98s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 463.72s of the 762.55s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.919	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.11s	 = Training   runtime
# (_dystack pid=8576) 	0.03s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 458.49s of the 757.32s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8958	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.64s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 451.94s of the 750.77s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9306	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.93s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 444.96s of the 743.79s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.919	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.83s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 440.21s of the 739.04s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9005	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.07s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 435.99s of the 734.82s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.92s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 431.01s of the 729.84s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.912	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.08s	 = Training   runtime
# (_dystack pid=8576) 	0.13s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 425.87s of the 724.7s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9005	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.96s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 420.76s of the 719.59s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8958	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.6s	 = Training   runtime
# (_dystack pid=8576) 	0.02s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 414.03s of the 712.86s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.912	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.24s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 407.69s of the 706.52s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9005	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.26s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 403.4s of the 702.23s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9074	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.36s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 396.04s of the 694.87s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9167	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.25s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 389.9s of the 688.73s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8843	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.79s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r135_BAG_L1 ... Training model for up to 384.98s of the 683.81s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9167	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.26s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r4_BAG_L1 ... Training model for up to 378.53s of the 677.36s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9167	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.86s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 373.72s of the 672.55s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.919	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.64s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 369.02s of the 667.86s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8981	 = Validation score   (accuracy)
# (_dystack pid=8576) 	7.79s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 359.19s of the 658.03s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9213	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.3s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 351.94s of the 650.77s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.8958	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.19s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 347.76s of the 646.59s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.912	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.36s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 342.34s of the 641.17s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9074	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.55s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: WeightedEnsemble_L2 ... Training model for up to 359.99s of the 635.43s of remaining time.
# (_dystack pid=8576) 	Ensemble Weights: {'NeuralNetFastAI_r143_BAG_L1': 0.8, 'NeuralNetFastAI_r102_BAG_L1': 0.1, 'NeuralNetFastAI_r37_BAG_L1': 0.1}
# (_dystack pid=8576) 	0.9352	 = Validation score   (accuracy)
# (_dystack pid=8576) 	0.06s	 = Training   runtime
# (_dystack pid=8576) 	0.0s	 = Validation runtime
# (_dystack pid=8576) Excluded models: ['KNN', 'GBM', 'CAT', 'XGB', 'RF', 'XT'] (Specified by `excluded_model_types`)
# (_dystack pid=8576) Fitting 44 L2 models ...
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 635.36s of the 635.31s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9282	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.85s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 630.59s of the 630.54s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9259	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.55s	 = Training   runtime
# (_dystack pid=8576) 	0.4s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 625.88s of the 625.82s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9468	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.51s	 = Training   runtime
# (_dystack pid=8576) 	0.39s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 620.25s of the 620.2s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9236	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.67s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 614.66s of the 614.61s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9444	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.92s	 = Training   runtime
# (_dystack pid=8576) 	0.34s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 608.71s of the 608.66s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9444	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.54s	 = Training   runtime
# (_dystack pid=8576) 	0.05s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 602.3s of the 602.24s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9329	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.5s	 = Training   runtime
# (_dystack pid=8576) 	0.02s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 596.76s of the 596.7s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.27s	 = Training   runtime
# (_dystack pid=8576) 	0.32s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 590.39s of the 590.33s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9352	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.33s	 = Training   runtime
# (_dystack pid=8576) 	0.4s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r11_BAG_L2 ... Training model for up to 585.16s of the 585.12s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9352	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.38s	 = Training   runtime
# (_dystack pid=8576) 	0.1s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r103_BAG_L2 ... Training model for up to 578.88s of the 578.84s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9167	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.04s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r14_BAG_L2 ... Training model for up to 573.73s of the 573.68s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9306	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.39s	 = Training   runtime
# (_dystack pid=8576) 	0.38s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r143_BAG_L2 ... Training model for up to 569.24s of the 569.19s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9375	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.05s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r156_BAG_L2 ... Training model for up to 562.2s of the 562.14s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.04s	 = Training   runtime
# (_dystack pid=8576) 	0.03s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r95_BAG_L2 ... Training model for up to 555.2s of the 555.15s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.54s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r41_BAG_L2 ... Training model for up to 549.8s of the 549.74s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9444	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.77s	 = Training   runtime
# (_dystack pid=8576) 	0.33s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r158_BAG_L2 ... Training model for up to 544.85s of the 544.81s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9398	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.98s	 = Training   runtime
# (_dystack pid=8576) 	0.37s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r37_BAG_L2 ... Training model for up to 538.9s of the 538.84s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9398	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.05s	 = Training   runtime
# (_dystack pid=8576) 	0.08s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r197_BAG_L2 ... Training model for up to 531.97s of the 531.91s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9468	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.29s	 = Training   runtime
# (_dystack pid=8576) 	0.4s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r134_BAG_L2 ... Training model for up to 527.64s of the 527.58s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	7.73s	 = Training   runtime
# (_dystack pid=8576) 	0.1s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r143_BAG_L2 ... Training model for up to 517.84s of the 517.78s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.86s	 = Training   runtime
# (_dystack pid=8576) 	0.38s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r111_BAG_L2 ... Training model for up to 511.06s of the 511.01s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9375	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.27s	 = Training   runtime
# (_dystack pid=8576) 	0.08s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r31_BAG_L2 ... Training model for up to 504.93s of the 504.87s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9444	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.82s	 = Training   runtime
# (_dystack pid=8576) 	0.38s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r65_BAG_L2 ... Training model for up to 499.94s of the 499.9s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9329	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.63s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r88_BAG_L2 ... Training model for up to 493.36s of the 493.31s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.9s	 = Training   runtime
# (_dystack pid=8576) 	0.12s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r87_BAG_L2 ... Training model for up to 486.46s of the 486.4s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9352	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.95s	 = Training   runtime
# (_dystack pid=8576) 	0.38s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r71_BAG_L2 ... Training model for up to 481.56s of the 481.5s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9352	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.3s	 = Training   runtime
# (_dystack pid=8576) 	0.36s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r185_BAG_L2 ... Training model for up to 477.29s of the 477.25s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9398	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.86s	 = Training   runtime
# (_dystack pid=8576) 	0.4s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r160_BAG_L2 ... Training model for up to 471.4s of the 471.35s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9282	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.14s	 = Training   runtime
# (_dystack pid=8576) 	0.08s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r69_BAG_L2 ... Training model for up to 466.22s of the 466.17s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9375	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.05s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r138_BAG_L2 ... Training model for up to 461.06s of the 461.01s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9352	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.91s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r172_BAG_L2 ... Training model for up to 454.04s of the 453.99s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9468	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.4s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r76_BAG_L2 ... Training model for up to 447.75s of the 447.7s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9398	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.39s	 = Training   runtime
# (_dystack pid=8576) 	0.4s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r121_BAG_L2 ... Training model for up to 443.3s of the 443.25s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9398	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.13s	 = Training   runtime
# (_dystack pid=8576) 	0.41s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r127_BAG_L2 ... Training model for up to 437.1s of the 437.06s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9398	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.23s	 = Training   runtime
# (_dystack pid=8576) 	0.04s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r194_BAG_L2 ... Training model for up to 430.98s of the 430.93s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9236	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.91s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r135_BAG_L2 ... Training model for up to 425.99s of the 425.94s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9375	 = Validation score   (accuracy)
# (_dystack pid=8576) 	4.23s	 = Training   runtime
# (_dystack pid=8576) 	0.36s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r4_BAG_L2 ... Training model for up to 419.55s of the 419.5s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9306	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.85s	 = Training   runtime
# (_dystack pid=8576) 	0.06s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r36_BAG_L2 ... Training model for up to 414.81s of the 414.76s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.93s	 = Training   runtime
# (_dystack pid=8576) 	0.4s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r100_BAG_L2 ... Training model for up to 409.65s of the 409.59s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	8.69s	 = Training   runtime
# (_dystack pid=8576) 	0.1s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetFastAI_r187_BAG_L2 ... Training model for up to 398.91s of the 398.85s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.01%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	5.24s	 = Training   runtime
# (_dystack pid=8576) 	0.07s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r19_BAG_L2 ... Training model for up to 391.7s of the 391.64s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9398	 = Validation score   (accuracy)
# (_dystack pid=8576) 	2.46s	 = Training   runtime
# (_dystack pid=8576) 	0.39s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r1_BAG_L2 ... Training model for up to 387.14s of the 387.09s of remaining time.
# (_dystack pid=8576) 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (10 workers, per: cpus=3, gpus=0, memory=0.00%)
# (_dystack pid=8576) 	0.9421	 = Validation score   (accuracy)
# (_dystack pid=8576) 	3.88s	 = Training   runtime
# (_dystack pid=8576) 	0.36s	 = Validation runtime
# (_dystack pid=8576) Fitting model: NeuralNetTorch_r89_BAG_L2 ... Training model for up to 381.26s of the 381.21s of remaining time.
# ...
# 	0.9014	 = Validation score   (accuracy)
# 	17.76s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2992.69s of the 2992.68s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9045	 = Validation score   (accuracy)
# 	36.79s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2954.37s of the 2954.36s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9168	 = Validation score   (accuracy)
# 	42.04s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2910.8s of the 2910.79s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9045	 = Validation score   (accuracy)
# 	20.92s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 2888.27s of the 2888.26s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9137	 = Validation score   (accuracy)
# 	40.94s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 2845.81s of the 2845.81s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9153	 = Validation score   (accuracy)
# 	28.32s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 2815.97s of the 2815.96s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9091	 = Validation score   (accuracy)
# 	20.2s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 2794.12s of the 2794.12s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9091	 = Validation score   (accuracy)
# 	44.62s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 2747.87s of the 2747.87s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9029	 = Validation score   (accuracy)
# 	37.9s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 2708.44s of the 2708.44s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9045	 = Validation score   (accuracy)
# 	21.92s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 2684.93s of the 2684.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9106	 = Validation score   (accuracy)
# 	18.84s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 2664.5s of the 2664.5s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8968	 = Validation score   (accuracy)
# 	30.16s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 2632.83s of the 2632.83s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9168	 = Validation score   (accuracy)
# 	29.39s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 2601.91s of the 2601.9s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.923	 = Validation score   (accuracy)
# 	30.91s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 2569.39s of the 2569.39s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9106	 = Validation score   (accuracy)
# 	20.16s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 2547.66s of the 2547.66s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9137	 = Validation score   (accuracy)
# 	34.8s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 2511.31s of the 2511.31s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9137	 = Validation score   (accuracy)
# 	44.88s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 2464.85s of the 2464.85s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8891	 = Validation score   (accuracy)
# 	18.2s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 2445.04s of the 2445.04s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9168	 = Validation score   (accuracy)
# 	29.9s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 2413.53s of the 2413.53s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9183	 = Validation score   (accuracy)
# 	41.08s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 2370.8s of the 2370.8s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9122	 = Validation score   (accuracy)
# 	53.11s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 2316.15s of the 2316.15s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9199	 = Validation score   (accuracy)
# 	25.87s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 2288.73s of the 2288.73s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9106	 = Validation score   (accuracy)
# 	34.25s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 2252.9s of the 2252.9s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9029	 = Validation score   (accuracy)
# 	30.4s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 2220.96s of the 2220.96s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9076	 = Validation score   (accuracy)
# 	29.9s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 2189.49s of the 2189.48s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9091	 = Validation score   (accuracy)
# 	35.35s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 2152.57s of the 2152.57s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.906	 = Validation score   (accuracy)
# 	29.35s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 2121.7s of the 2121.7s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9076	 = Validation score   (accuracy)
# 	38.41s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 2081.76s of the 2081.76s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9029	 = Validation score   (accuracy)
# 	18.47s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 2061.74s of the 2061.74s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8983	 = Validation score   (accuracy)
# 	18.23s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 2041.93s of the 2041.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9122	 = Validation score   (accuracy)
# 	22.77s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 2017.57s of the 2017.57s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9106	 = Validation score   (accuracy)
# 	16.67s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 1999.27s of the 1999.27s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9045	 = Validation score   (accuracy)
# 	29.67s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 1968.08s of the 1968.07s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9091	 = Validation score   (accuracy)
# 	44.71s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 1921.83s of the 1921.83s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9153	 = Validation score   (accuracy)
# 	26.75s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 1893.53s of the 1893.53s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.8998	 = Validation score   (accuracy)
# 	17.4s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135_BAG_L1 ... Training model for up to 1874.53s of the 1874.52s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9137	 = Validation score   (accuracy)
# 	45.71s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4_BAG_L1 ... Training model for up to 1827.25s of the 1827.24s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9153	 = Validation score   (accuracy)
# 	17.52s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 1808.17s of the 1808.17s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9137	 = Validation score   (accuracy)
# 	33.8s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 1772.84s of the 1772.83s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9106	 = Validation score   (accuracy)
# 	39.25s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 1732.03s of the 1732.03s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9214	 = Validation score   (accuracy)
# 	30.67s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 1699.78s of the 1699.78s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9045	 = Validation score   (accuracy)
# 	31.63s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 1666.63s of the 1666.63s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9153	 = Validation score   (accuracy)
# 	42.2s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 1622.84s of the 1622.84s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=16, gpus=0, memory=0.00%)
# 	0.9106	 = Validation score   (accuracy)
# 	38.91s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1582.25s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r156_BAG_L1': 0.65, 'NeuralNetTorch_r22_BAG_L1': 0.15, 'NeuralNetFastAI_r187_BAG_L1': 0.1, 'NeuralNetTorch_r197_BAG_L1': 0.05, 'NeuralNetTorch_r1_BAG_L1': 0.05}
# 	0.9276	 = Validation score   (accuracy)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1429.86s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 252.8 rows/s (65 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("GPU_1_SPD_DL_VALIDATION_kfold")
# GPU_1_SPD_DL_VALIDATION_kfold_TIME_33.67_EMISSION_0.034498.csv

# %%
class_distribution_post = df_selected['G3'].value_counts()
print("Class Dist:")
print(class_distribution_post)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 class_distribution_post = df_selected['G3'].value_counts()
#       2 print("Class Dist:")
#       3 print(class_distribution_post)
#
# NameError: name 'df_selected' is not defined
